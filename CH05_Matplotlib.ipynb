# %% [markdown]
# # Matplotlib을 활용한 시각화

# %% [markdown]
# ## 1. 일반적인 Matplotlib 사용법

# %%
#matplotlib 임포트하기
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#스타일 설정하기
plt.style.use('classic')

# %%
#스크립트에서 플로팅하기
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
#매트랩 스타일의 인터페이스
# 두개의 패널 중 첫번째 패널을 생성하고 현재 축(axis)을 설정
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
#플롯 수정하기: 선 색상과 스타일
plt.plot(x, np.sin(x - 0), color='blue')           # 색상을 이름으로 지정
plt.plot(x, np.sin(x - 1), color='g')              # 짧은 색상 코드(rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')           # 0과 1 사이로 회색조 지정
plt.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3))  # RGB 튜플, 0과 1 값
plt.show()

# %%
plt.plot(x ,x + 0, linestyle='solid')      #linestyle='-'
plt.plot(x, x + 1, linestyle='dashed')     #linestyle='--'
plt.plot(x, x + 2, linestyle='dashdot')    #linestyle='-.'
plt.plot(x, x + 3, linestyle='dotted')     #linestyle=':'
plt.show()

# %%
# RGB(Red, 빨강 / Green, 녹색 / Blue, 파랑)와 CMYK(Cyan, 청록 / Magenta, 자홍 / Yellow, 노랑 / blacK, 검정)
plt.plot(x, x + 0, '-g')      #solid green
plt.plot(x, x + 1, '--c')     #dashed cyan
plt.plot(x, x + 2, '-.k')     #dashdot black
plt.plot(x, x + 3, ':r')      #dotted red

# %%
# 플롯 조정하기: 축 경계
plt.subplot(3, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(3, 1, 2)
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)        # x축 범위 -1 ~ 11로 지정
plt.ylim(-1.5, 1.5)     # y축 범위 -1.5 ~ 1.5로 지정

plt.subplot(3, 1, 3)
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])

plt.show()

# %%
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))
plt.axis('tight')       # plt.axis('tight') 이라는 메서드를 이용하면 현재 플롯 주변의 경계를 자동으로 더 밀착시키는 작업 또한 할 수 있음.

plt.subplot(2, 1, 2)
plt.plot(x, np.sin(x))
plt.axis('equal')       # plt.axis('equal') 이라는 메서드를 이용하면 가로세로 비율을 균득하게 설정하는 작업 또한 할 수 있음.

plt.show()

# %%
#플롯에 레이블 붙이기
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")

plt.show()

# %% [markdown]
# ## 2. 히스토그램

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  3.,  19.,  83., 200., 273., 224., 124.,  52.,  16.,   6.]),
#  array([-3.25001118, -2.57766309, -1.90531499, -1.2329669 , -0.56061881,
#          0.11172929,  0.78407738,  1.45642547,  2.12877357,  2.80112166,
#          3.47346975]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data);

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none');
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6510: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
# 예제 - Mnist
from sklearn.datasets import load_digits

digits = load_digits(n_class=6)
fig, ax = plt.subplots(8, 8, figsize=(6, 6))

for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xticks=[], yticks=[])

# %% [markdown]
# # Seaborn을 활용한 데이터 분포 시각화

# %% [markdown]
# ## 1. Seaborn과 Matplotlib의 차이

# %%
# Seaborn과 Matplotlib의 차이
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')
plt.show()

# %% [markdown]
# ## 2. 1차원 분포 플롯

# %% [markdown]
# #### 1차원 데이터는 실수 값이면 히스토그램과 같은 실수 분포 플롯으로 나타내고 카테고리 값이면 카운트 플롯으로 나타낸다.
# #### 우선 연습을 위한 샘플 데이터를 로드한다.

# %%
iris = sns.load_dataset("iris") #붓꽃 데이터
titanic = sns.load_dataset("titanic") #타이타닉호 데이터
tips = sns.load_dataset("tips") #팁 데이터
flights = sns.load_dataset("flights") #여객운송 데이터

# %% [markdown]
# ### 2-1. 1차원 실수 분포 플롯

# %% [markdown]
# #### 실수 분포 플롯은 자료의 분포를 묘사하기 위한 것으로 Matplotlib의 단순한 히스토그램고 달리 커널 밀도(kernal density) 및 러그(rug) 표시 기능 및 다차원 복합 분포 기능 등을 제공한다.
# #### 1차원 실수 분포 플롯 명령에는 rugplot, kdeplot, distplot 이 있다.
# * 러그(rug) 플롯은 데이터 위치를 x축 위에 작은 선분(rug)으로 나타내어 실제 데이터들의 위치를 보여준다.
#     * rugplot : http://seaborn.pydata.org/generated/seaborn.rugplot.html

# %%
x = iris.petal_length.values

# %%
sns.rugplot(x)
plt.title("'Rug Plot' about petal length in Iris Data")
plt.show()

# %% [markdown]
# * 커널 밀도(kernal density)는 커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여주는 방법이다.
#     * kdeplot : http://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %%
sns.kdeplot(x)
plt.title("'Kernal Density Plot' about petal length in Iris Data")
plt.show()

# %% [markdown]
# * distplot 명령은 러그와 커널 밀도 표시 기능이 있어서 Matplotlib의 hist 명령보다 많이 사용된다.
#     * distplot : http://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
sns.distplot(x, kde=True, rug=True)
plt.title("'Dist Plot' about petal length in Iris Data")
plt.show()

# %% [markdown]
# ### 2-2. 카운트 플롯

# %% [markdown]
# * countplot 명령을 사용하면 각 카테고리 값별로 데이터가 얼마나 있는지 표시할 수 있다.
#     * countplot : http://seaborn.pydata.org/generated/seaborn.countplot.html

# %% [markdown]
# * countplot 명령은 데이터프레임에만 사용할 수 있다. 사용 방법은 다음과 같다.

# %% [markdown]
# countplot(x="class_name", data=dataframe)

# %% [markdown]
# * x 인수에는 데이터프레임의 열 이름 문자열을, data 인수에는 대상이 되는 데이터프레임을 넣는다.

# %%
sns.countplot(x="class", data=titanic)
plt.title("Number of passengers per class of Titanic")
plt.show()

# %%
sns.countplot(x="day", data=tips)
plt.title("Number of times a day's tip was given")
plt.show()
